# %% [markdown]
# # Quantize a Stable Diffusion Model with OpenVINO
#
# This notebook shows how to quantize a diffusion model with OpenVINO's [Neural Network Compression Framework](https://github.com/openvinotoolkit/nncf) (NNCF).
#
# With quantization, we reduce the precision of the model's weights and activations from floating point (FP32) to integer (INT8). This results in a smaller model with faster inference times with OpenVINO Runtime.
#
# Traditional optimization methods like post-training 8-bit quantization do not work well for Stable Diffusion models and can lead to poor generation results. On the other hand, weight compression does not improve performance significantly when applied to Stable Diffusion models, as the size of activations is comparable to weights. The UNet model takes up most of the overall execution time of the pipeline. Thus, optimizing just one model brings substantial benefits in terms of inference speed while keeping acceptable accuracy without fine-tuning. Quantizing the rest of the diffusion pipeline does not significantly improve inference performance but could potentially lead to substantial degradation of accuracy.
#
# Therefore, the proposal is to apply quantization in *hybrid mode* for the UNet model and weight-only quantization for the rest of the pipeline components. The hybrid mode involves the quantization of weights in MatMul and Embedding layers, and activations of other layers, facilitating accuracy preservation post-optimization while reducing the model size.
# For more details refers to [documentation](https://github.com/huggingface/optimum-intel/blob/main/docs/source/optimization_ov.mdx).
#
# The notebook demonstrates post-training quantization in *hybrid mode*, which does not require specific hardware to execute. A laptop or desktop with a recent Intel Core processor is recommended for best results. To install the requirements for this notebook, please do `pip install -r requirements.txt` or uncomment the cell below to install the requirements in your current Python environment.

# %%
# %pip install "optimum-intel[openvino]" datasets ipywidgets

# %%
import time
import datasets
import matplotlib.pyplot as plt
import numpy as np
import transformers
from pathlib import Path
from openvino import Core
from optimum.intel import OVConfig, OVQuantizer, OVStableDiffusionPipeline, OVWeightQuantizationConfig
from optimum.intel.openvino.configuration import OVQuantizationMethod

transformers.logging.set_verbosity_error()
datasets.logging.set_verbosity_error()

# %% [markdown]
# ## Settings
#
# For this tutorial, we use the [jxie/coco_captions](https://huggingface.co/datasets/jxie/coco_captions), dataset contains over 120,000 images, each annotated with multiple captions describing the objects and activities depicted in the image. The notebook was tested with the [stabilityai/stable-diffusion-2-1](https://huggingface.co/stabilityai/stable-diffusion-2-1) model. Other [stable diffusion models](https://huggingface.co/models?pipeline_tag=text-to-image) for text-to-image generation should also work.

# %%
MODEL_ID = "stabilityai/stable-diffusion-2-1"
DATASET_NAME = "jxie/coco_captions"

base_model_path = Path(f"models/{MODEL_ID}")
fp32_model_path = base_model_path.with_name(base_model_path.name + "_FP32")
int8_model_path = base_model_path.with_name(base_model_path.name + "_INT8")

# %% [markdown]
# ## Post-training Hybrid Quantization

# %% [markdown]
# To perform post-training optimization on the `OVStableDiffusionPipeline`, you need to provide the `quantization_config` to the `from_pretrained` method.
# The `quantization_config` is utilized to define optimization parameters for optimizing the Stable Diffusion pipeline. To enable hybrid quantization, specify the quantization dataset in the `quantization_config`. Otherwise, weight-only quantization to a specified data type (8 or 4 bits) is applied to UNet model.
# That's all!

# %% [markdown]
# ### Prepare the Dataset
#
# We need a small representative calibration dataset to quantize the model. For text-to-image generation we should collect text descriptions or prompts that provide information about the desired image. The `COCO Captions` dataset primarily consists of images paired with multiple human-generated captions describing the contents of the image. Thus, we'll take the `caption` column, which contains descriptions corresponding to the images, as our calibration data.
#
# The `datasets` library makes it easy to load datasets. Common datasets can be loaded from the Hugging Face Hub by providing the name of the dataset. See https://github.com/huggingface/datasets. We can load the `jxie/coco_captions` dataset with `load_dataset` and show a random dataset item.

# %%
dataset = datasets.load_dataset(DATASET_NAME, split="train", streaming=True).shuffle(seed=42)
print(next(iter(dataset)))
# Out:
# Resolving data files:   0%|          | 0/182 [00:00<?, ?it/s]
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7FC5721034D0>, 'filename': 'COCO_train2014_000000494175.jpg', 'cocoid': 494175, 'caption': 'A crowded arena filled with people and confetti.'}

# %%
def preprocess_fn(example):
    return {"prompt": example["caption"]}

NUM_SAMPLES = 200
prompts = [example["caption"] for example in dataset.take(NUM_SAMPLES)]

# %% [markdown]
# ### Quantize the Model
#
# We load the model from the Hugging Face Hub. The model will be automatically downloaded if it has not been downloaded before, or loaded from the cache otherwise.

# %%
int8_pipe = OVStableDiffusionPipeline.from_pretrained(model_id=MODEL_ID, export=True)
quantization_config = OVWeightQuantizationConfig(bits=8, num_samples=NUM_SAMPLES, quant_method=OVQuantizationMethod.HYBRID)
quantizer = OVQuantizer(int8_pipe)
quantizer.quantize(
    ov_config=OVConfig(quantization_config=quantization_config, dataset=prompts),
    save_directory=int8_model_path
)
# Out:
# Keyword arguments {'subfolder': '', 'trust_remote_code': False} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/transformers/modeling_attn_mask_utils.py:88: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if input_shape[-1] > 1 or self.sliding_window is not None:
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/transformers/modeling_attn_mask_utils.py:164: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if past_key_values_length > 0:
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_condition.py:1249: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if dim % default_overall_up_factor != 0:
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/downsampling.py:136: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/downsampling.py:145: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/upsampling.py:146: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/upsampling.py:162: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if hidden_states.shape[0] >= 64:
# You have disabled the safety checker for <class 'optimum.intel.openvino.modeling_diffusion.OVStableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │ Weight compression mode   │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ int8_asym                 │ 100% (32 / 32)              │ 100% (32 / 32)                         │
# ┕━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │ Weight compression mode   │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ int8_asym                 │ 100% (40 / 40)              │ 100% (40 / 40)                         │
# ┕━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │ Weight compression mode   │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ int8_asym                 │ 100% (140 / 140)            │ 100% (140 / 140)                       │
# ┕━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:66 ignored nodes were found by types in the NNCFGraph
# INFO:nncf:66 ignored nodes were found by types in the NNCFGraph
# INFO:nncf:Statistics of the bitwidth distribution:
# ┍━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │ Weight compression mode   │ % all parameters (layers)   │ % ratio-defining parameters (layers)   │
# ┝━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ int8_asym                 │ 100% (216 / 216)            │ 100% (216 / 216)                       │
# ┕━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO:nncf:216 ignored nodes were found by names in the NNCFGraph
# INFO:nncf:Not adding activation input quantizer for operation: 10 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 11 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 12 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 13 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 14 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 15 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 16 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 17 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 18 __module.mid_block.attentions.0.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 19 __module.mid_block.attentions.0.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 20 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 21 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 22 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 23 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 24 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 25 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 26 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 27 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 28 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 29 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 30 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 31 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 32 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 33 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 34 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 35 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 36 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 37 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 6 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 7 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 8 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 9 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 275 __module.time_embedding.linear_1/aten::linear/MatMul
# 312 __module.time_embedding.linear_1/aten::linear/Add
# 365 __module.conv_act/aten::silu/Swish_1
#
# INFO:nncf:Not adding activation input quantizer for operation: 420 __module.time_embedding.linear_2/aten::linear/MatMul
# 477 __module.time_embedding.linear_2/aten::linear/Add
# 532 __module.conv_act/aten::silu/Swish_2
#
# INFO:nncf:Not adding activation input quantizer for operation: 587 __module.down_blocks.0.resnets.0.time_emb_proj/aten::linear/MatMul
# 676 __module.down_blocks.0.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 588 __module.down_blocks.0.resnets.1.time_emb_proj/aten::linear/MatMul
# 677 __module.down_blocks.0.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 589 __module.down_blocks.1.resnets.0.time_emb_proj/aten::linear/MatMul
# 678 __module.down_blocks.1.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 590 __module.down_blocks.1.resnets.1.time_emb_proj/aten::linear/MatMul
# 679 __module.down_blocks.1.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 591 __module.down_blocks.2.resnets.0.time_emb_proj/aten::linear/MatMul
# 680 __module.down_blocks.2.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 592 __module.down_blocks.2.resnets.1.time_emb_proj/aten::linear/MatMul
# 681 __module.down_blocks.2.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 593 __module.down_blocks.3.resnets.0.time_emb_proj/aten::linear/MatMul
# 682 __module.down_blocks.3.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 594 __module.down_blocks.3.resnets.1.time_emb_proj/aten::linear/MatMul
# 683 __module.down_blocks.3.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 595 __module.mid_block.resnets.0.time_emb_proj/aten::linear/MatMul
# 684 __module.mid_block.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 596 __module.mid_block.resnets.1.time_emb_proj/aten::linear/MatMul
# 685 __module.mid_block.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 597 __module.up_blocks.0.resnets.0.time_emb_proj/aten::linear/MatMul
# 686 __module.up_blocks.0.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 598 __module.up_blocks.0.resnets.1.time_emb_proj/aten::linear/MatMul
# 687 __module.up_blocks.0.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 599 __module.up_blocks.0.resnets.2.time_emb_proj/aten::linear/MatMul
# 688 __module.up_blocks.0.resnets.2.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 600 __module.up_blocks.1.resnets.0.time_emb_proj/aten::linear/MatMul
# 689 __module.up_blocks.1.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 601 __module.up_blocks.1.resnets.1.time_emb_proj/aten::linear/MatMul
# 690 __module.up_blocks.1.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 602 __module.up_blocks.1.resnets.2.time_emb_proj/aten::linear/MatMul
# 691 __module.up_blocks.1.resnets.2.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 603 __module.up_blocks.2.resnets.0.time_emb_proj/aten::linear/MatMul
# 692 __module.up_blocks.2.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 604 __module.up_blocks.2.resnets.1.time_emb_proj/aten::linear/MatMul
# 693 __module.up_blocks.2.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 605 __module.up_blocks.2.resnets.2.time_emb_proj/aten::linear/MatMul
# 694 __module.up_blocks.2.resnets.2.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 606 __module.up_blocks.3.resnets.0.time_emb_proj/aten::linear/MatMul
# 695 __module.up_blocks.3.resnets.0.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 607 __module.up_blocks.3.resnets.1.time_emb_proj/aten::linear/MatMul
# 696 __module.up_blocks.3.resnets.1.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 608 __module.up_blocks.3.resnets.2.time_emb_proj/aten::linear/MatMul
# 697 __module.up_blocks.3.resnets.2.time_emb_proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 187 __module.down_blocks.0.attentions.0.proj_in/aten::linear/MatMul
# 221 __module.down_blocks.0.attentions.0.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 398 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 399 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 400 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 865 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 976 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 456 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 204 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 238 __module.down_blocks.0.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 478 __module.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 533 __module.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 806 __module.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 913 __module.down_blocks.0.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 367 __module.down_blocks.0.attentions.0.proj_out/aten::linear/MatMul
# 422 __module.down_blocks.0.attentions.0.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 258 __module.down_blocks.0.attentions.1.proj_in/aten::linear/MatMul
# 296 __module.down_blocks.0.attentions.1.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 509 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 510 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 511 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1065 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1121 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 565 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 205 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 239 __module.down_blocks.0.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 479 __module.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 534 __module.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 809 __module.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 916 __module.down_blocks.0.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 369 __module.down_blocks.0.attentions.1.proj_out/aten::linear/MatMul
# 424 __module.down_blocks.0.attentions.1.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 566 __module.down_blocks.1.attentions.0.proj_in/aten::linear/MatMul
# 654 __module.down_blocks.1.attentions.0.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1066 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1067 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1068 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1306 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1330 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1125 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 206 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 240 __module.down_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 480 __module.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 535 __module.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 812 __module.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 919 __module.down_blocks.1.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 371 __module.down_blocks.1.attentions.0.proj_out/aten::linear/MatMul
# 426 __module.down_blocks.1.attentions.0.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 761 __module.down_blocks.1.attentions.1.proj_in/aten::linear/MatMul
# 870 __module.down_blocks.1.attentions.1.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1178 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1179 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1180 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1355 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1383 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1229 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 207 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 241 __module.down_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 482 __module.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 537 __module.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 815 __module.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 922 __module.down_blocks.1.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 373 __module.down_blocks.1.attentions.1.proj_out/aten::linear/MatMul
# 428 __module.down_blocks.1.attentions.1.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1230 __module.down_blocks.2.attentions.0.proj_in/aten::linear/MatMul
# 1267 __module.down_blocks.2.attentions.0.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1356 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1357 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1358 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1464 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1470 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1387 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 208 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 242 __module.down_blocks.2.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 484 __module.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 539 __module.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 818 __module.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 925 __module.down_blocks.2.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 375 __module.down_blocks.2.attentions.0.proj_out/aten::linear/MatMul
# 430 __module.down_blocks.2.attentions.0.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1101 __module.down_blocks.2.attentions.1.proj_in/aten::linear/MatMul
# 1157 __module.down_blocks.2.attentions.1.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1295 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1296 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1297 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1438 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1452 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1321 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 209 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 243 __module.down_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 486 __module.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 541 __module.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 826 __module.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 934 __module.down_blocks.2.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 377 __module.down_blocks.2.attentions.1.proj_out/aten::linear/MatMul
# 432 __module.down_blocks.2.attentions.1.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1279 __module.mid_block.attentions.0.proj_in/aten::linear/MatMul
# 1301 __module.mid_block.attentions.0.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1398 __module.mid_block.attentions.0.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1399 __module.mid_block.attentions.0.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1400 __module.mid_block.attentions.0.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1472 __module.mid_block.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1475 __module.mid_block.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1425 __module.mid_block.attentions.0.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 210 __module.mid_block.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 244 __module.mid_block.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 488 __module.mid_block.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 543 __module.mid_block.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 832 __module.mid_block.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 942 __module.mid_block.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 379 __module.mid_block.attentions.0.proj_out/aten::linear/MatMul
# 434 __module.mid_block.attentions.0.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1260 __module.up_blocks.1.attentions.0.proj_in/aten::linear/MatMul
# 1280 __module.up_blocks.1.attentions.0.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1375 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1376 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1377 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1468 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1473 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1405 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 211 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 245 __module.up_blocks.1.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 490 __module.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 545 __module.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 837 __module.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 948 __module.up_blocks.1.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 381 __module.up_blocks.1.attentions.0.proj_out/aten::linear/MatMul
# 436 __module.up_blocks.1.attentions.0.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1255 __module.up_blocks.1.attentions.1.proj_in/aten::linear/MatMul
# 1278 __module.up_blocks.1.attentions.1.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1369 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1370 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1371 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1466 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1471 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1397 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 212 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 246 __module.up_blocks.1.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 492 __module.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 547 __module.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 840 __module.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 951 __module.up_blocks.1.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 383 __module.up_blocks.1.attentions.1.proj_out/aten::linear/MatMul
# 438 __module.up_blocks.1.attentions.1.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1261 __module.up_blocks.1.attentions.2.proj_in/aten::linear/MatMul
# 1281 __module.up_blocks.1.attentions.2.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1379 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1380 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1381 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1469 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1474 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1409 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 213 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 247 __module.up_blocks.1.attentions.2.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 494 __module.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 549 __module.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 845 __module.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 956 __module.up_blocks.1.attentions.2.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 385 __module.up_blocks.1.attentions.2.proj_out/aten::linear/MatMul
# 440 __module.up_blocks.1.attentions.2.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1184 __module.up_blocks.2.attentions.0.proj_in/aten::linear/MatMul
# 1231 __module.up_blocks.2.attentions.0.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1334 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1335 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1336 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1459 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1465 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1363 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 214 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 248 __module.up_blocks.2.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 496 __module.up_blocks.2.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 551 __module.up_blocks.2.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 849 __module.up_blocks.2.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 960 __module.up_blocks.2.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 387 __module.up_blocks.2.attentions.0.proj_out/aten::linear/MatMul
# 442 __module.up_blocks.2.attentions.0.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1077 __module.up_blocks.2.attentions.1.proj_in/aten::linear/MatMul
# 1132 __module.up_blocks.2.attentions.1.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1289 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1290 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1291 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1437 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1451 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1315 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 215 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 249 __module.up_blocks.2.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 498 __module.up_blocks.2.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 553 __module.up_blocks.2.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 852 __module.up_blocks.2.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 963 __module.up_blocks.2.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 389 __module.up_blocks.2.attentions.1.proj_out/aten::linear/MatMul
# 444 __module.up_blocks.2.attentions.1.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 665 __module.up_blocks.2.attentions.2.proj_in/aten::linear/MatMul
# 770 __module.up_blocks.2.attentions.2.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1134 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1135 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1136 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1342 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1366 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1191 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 216 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 250 __module.up_blocks.2.attentions.2.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 500 __module.up_blocks.2.attentions.2.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 555 __module.up_blocks.2.attentions.2.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 855 __module.up_blocks.2.attentions.2.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 966 __module.up_blocks.2.attentions.2.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 391 __module.up_blocks.2.attentions.2.proj_out/aten::linear/MatMul
# 446 __module.up_blocks.2.attentions.2.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 525 __module.up_blocks.3.attentions.0.proj_in/aten::linear/MatMul
# 579 __module.up_blocks.3.attentions.0.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 992 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 993 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 994 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1294 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1317 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 1084 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 217 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 251 __module.up_blocks.3.attentions.0.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 502 __module.up_blocks.3.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 557 __module.up_blocks.3.attentions.0.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 858 __module.up_blocks.3.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 969 __module.up_blocks.3.attentions.0.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 393 __module.up_blocks.3.attentions.0.proj_out/aten::linear/MatMul
# 448 __module.up_blocks.3.attentions.0.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 413 __module.up_blocks.3.attentions.1.proj_in/aten::linear/MatMul
# 472 __module.up_blocks.3.attentions.1.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 774 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 775 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 776 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1239 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1275 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 886 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 218 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 252 __module.up_blocks.3.attentions.1.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 503 __module.up_blocks.3.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 558 __module.up_blocks.3.attentions.1.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 861 __module.up_blocks.3.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 972 __module.up_blocks.3.attentions.1.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 395 __module.up_blocks.3.attentions.1.proj_out/aten::linear/MatMul
# 450 __module.up_blocks.3.attentions.1.proj_out/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 308 __module.up_blocks.3.attentions.2.proj_in/aten::linear/MatMul
# 361 __module.up_blocks.3.attentions.2.proj_in/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 583 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn1.to_k/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 584 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn1.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 585 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn1.to_v/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 1143 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn1.to_out.0/aten::linear/MatMul
# 1195 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn1.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 675 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn2.to_q/aten::linear/MatMul
# INFO:nncf:Not adding activation input quantizer for operation: 219 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn2.to_out.0/aten::linear/MatMul
# 253 __module.up_blocks.3.attentions.2.transformer_blocks.0.attn2.to_out.0/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 504 __module.up_blocks.3.attentions.2.transformer_blocks.0.ff.net.0.proj/aten::linear/MatMul
# 559 __module.up_blocks.3.attentions.2.transformer_blocks.0.ff.net.0.proj/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 864 __module.up_blocks.3.attentions.2.transformer_blocks.0.ff.net.2/aten::linear/MatMul
# 975 __module.up_blocks.3.attentions.2.transformer_blocks.0.ff.net.2/aten::linear/Add
#
# INFO:nncf:Not adding activation input quantizer for operation: 397 __module.up_blocks.3.attentions.2.proj_out/aten::linear/MatMul
# 452 __module.up_blocks.3.attentions.2.proj_out/aten::linear/Add
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Compare INT8 and FP32 models
#
# We create two pipelines: `int8_pipe` and `fp32_pipe` to compare the FP32 and INT8 OpenVINO models. These pipelines will be used for benchmarking later in this notebook.

# %%
fp32_pipe = OVStableDiffusionPipeline.from_pretrained(model_id=MODEL_ID, export=True)
fp32_pipe.save_pretrained(fp32_model_path)
# Out:
# Keyword arguments {'subfolder': '', 'trust_remote_code': False} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/transformers/modeling_attn_mask_utils.py:88: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if input_shape[-1] > 1 or self.sliding_window is not None:
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/transformers/modeling_attn_mask_utils.py:164: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if past_key_values_length > 0:
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_condition.py:1249: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if dim % default_overall_up_factor != 0:
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/downsampling.py:136: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/downsampling.py:145: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/upsampling.py:146: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /home/ltalamanova/tmp_venv/lib/python3.11/site-packages/diffusers/models/upsampling.py:162: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if hidden_states.shape[0] >= 64:
# You have disabled the safety checker for <class 'optimum.intel.openvino.modeling_diffusion.OVStableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %% [markdown]
# ### Visual Accuracy
# Let us check predictions between the original and optimized pipelines using the same prompt.

# %%
def visualize_results(fp32_img, int8_img):
    im_w, im_h = fp32_img.size
    is_horizontal = im_h <= im_w
    figsize = (20, 30) if is_horizontal else (30, 20)
    fig, axs = plt.subplots(1 if is_horizontal else 2, 2 if is_horizontal else 1, figsize=figsize, sharex='all', sharey='all')
    fig.patch.set_facecolor('white')
    list_axes = list(axs.flat)
    for a in list_axes:
        a.set_xticklabels([])
        a.set_yticklabels([])
        a.get_xaxis().set_visible(False)
        a.get_yaxis().set_visible(False)
        a.grid(False)
    list_axes[0].imshow(np.array(fp32_img))
    list_axes[1].imshow(np.array(int8_img))
    img1_title = "FP32 result"
    img2_title = "INT8 result"
    list_axes[0].set_title(img1_title, fontsize=20)
    list_axes[1].set_title(img2_title, fontsize=20)
    fig.subplots_adjust(wspace=0.0 if is_horizontal else 0.01 , hspace=0.01 if is_horizontal else 0.0)
    fig.tight_layout()

# %%
prompt = "Self-portrait oil painting, a beautiful cyborg with golden hair, 8k"

def generate_image(pipeline, prompt):
    transformers.set_seed(1)
    return pipeline(
        prompt=prompt,
        guidance_scale=8.0,
        output_type="pil"
    ).images[0]

# %%
fp32_img = generate_image(fp32_pipe, prompt)
int8_img = generate_image(int8_pipe, prompt)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
visualize_results(fp32_img, int8_img)

# %% [markdown]
# ### Model Size
#
# We save the FP32 PyTorch model and define a function to show the model size for the PyTorch and OpenVINO models.

# %%
def get_model_size(model_folder, framework):
    """
    Return OpenVINO or PyTorch model size in Mb.
    
    Arguments:
        model_folder:
            Directory containing a model.
        framework:
            Define whether the model is a PyTorch or an OpenVINO model.
    """
    model_size = 0
    if framework.lower() == "openvino":
        for model_path in Path(model_folder).rglob("*.xml"):
            model_size += model_path.stat().st_size

    extension = "*.bin" if framework.lower() == "openvino" else "*.safetensors"
    for model_path in Path(model_folder).rglob(extension):
        model_size += model_path.stat().st_size
    model_size /= 2**20
    return model_size

# %%
fp32_model_size = get_model_size(fp32_model_path, "openvino")
int8_model_size = get_model_size(int8_model_path, "openvino")
print(f"FP32 model size: {fp32_model_size:.2f} MB")
print(f"INT8 model size: {int8_model_size:.2f} MB")
print(f"INT8 size decrease: {fp32_model_size / int8_model_size:.2f}x")
# Out:
# FP32 model size: 4923.07 MB
# INT8 model size: 1238.31 MB
# INT8 size decrease: 3.98x

# %% [markdown]
# ### Latency
#
# Compare the inference speed of the quantized OpenVINO model with that of the original PyTorch model.
#
# This benchmark provides an estimate of performance, but keep in mind that other programs running on the computer, as well as power management settings, can affect performance.

# %%
def get_val_dataset(num_items=3):
    return [item["caption"] for item in dataset.take(num_items)]

def benchmark(pipeline, dataset):
    """
    Benchmark PyTorch or OpenVINO model. This function does inference on `num_items`
    dataset items and returns the median latency in milliseconds
    """
    latencies = []
    for prompt in dataset:
        start_time = time.perf_counter()
        _ = pipeline(prompt=prompt)
        end_time = time.perf_counter()
        latencies.append(end_time - start_time)
    return np.median(latencies) * 1000


cpu_device_name = Core().get_property("CPU", "FULL_DEVICE_NAME")
print(cpu_device_name)

val_subset = get_val_dataset()
original_latency = benchmark(fp32_pipe, val_subset)
print(f"Latency of original FP32 model: {original_latency:.2f} ms")

quantized_latency = benchmark(int8_pipe, val_subset)
print(f"Latency of quantized model: {quantized_latency:.2f} ms")
print(f"Speedup: {(original_latency/quantized_latency):.2f}x")
# Out:
# Intel(R) Core(TM) i9-10980XE CPU @ 3.00GHz
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Latency of original FP32 model: 180307.04 ms
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Latency of quantized model: 154601.10 ms
# Speedup: 1.17x
